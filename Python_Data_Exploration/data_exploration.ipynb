# %%
# installing the spotipy package
# !pip install spotipy
# Out:
# ...
#   Obtaining dependency information for spotipy from https://files.pythonhosted.org/packages/c9/9c/229d432e223e614f7dbe5de626d3713094f03af79a6f5dbc1bbdf7d95ae8/spotipy-2.25.0-py3-none-any.whl.metadata
#   Using cached spotipy-2.25.0-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Obtaining dependency information for redis>=3.5.3 from https://files.pythonhosted.org/packages/3c/5f/fa26b9b2672cbe30e07d9a5bdf39cf16e3b80b42916757c5f92bca88e4ba/redis-5.2.1-py3-none-any.whl.metadata
#   Using cached redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# ...
# Using cached spotipy-2.25.0-py3-none-any.whl (30 kB)
# Using cached redis-5.2.1-py3-none-any.whl (261 kB)
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %% [markdown]
# ### Connecting to Spotify API with Client ID and Client Secret

# %%
client_credentials_manager = SpotifyClientCredentials(client_id= "XXXXXX", client_secret= "XXXXXX")     # replace with client id and client secret

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# ### Reading The 100 most streamed songs on Spotify

# %%
playlist_link = "https://open.spotify.com/playlist/5ABHKGoOzxkaa28ttQV9sE"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/5ABHKGoOzxkaa28ttQV9sE/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-02-15T21:57:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#     'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#     'id': 'jonathan.holgersson',
#     'type': 'user',
#     'uri': 'spotify:user:jonathan.holgersson'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
# ...

# %% [markdown]
# ### Extracting Album Details

# %%
album_list = []
for row in data["items"]:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']

    # creating a dictionary for all the album elements
    album_element = {'album_id': album_id, 
                    'album_name': album_name,
                    'album_release_date': album_release_date,
                    'album_total_tracks': album_total_tracks,
                    'album_url': album_url}
    
    # adding the dictionary to the album list
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'album_name': 'After Hours',
#   'album_release_date': '2020-03-20',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#  {'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'album_name': '÷ (Deluxe)',
#   'album_release_date': '2017-03-03',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': '5658aM19fA3JVwTK6eQX70',
#   'album_name': 'Divinely Uninspired To A Hellish Extent',
#   'album_release_date': '2019-05-17',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/5658aM19fA3JVwTK6eQX70'},
#  {'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'album_name': "Harry's House",
#   'album_release_date': '2022-05-20',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#  {'album_id': '09fggMHib4YkOtwQNXEBII',
#   'album_name': 'Starboy',
# ...

# %%
data['items'][0]['track']['album']['artists'][0]['name']
# Out:
# 'The Weeknd'

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-02-15T21:57:53Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#   'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#   'id': 'jonathan.holgersson',
#   'type': 'user',
#   'uri': 'spotify:user:jonathan.holgersson'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
# ...

# %% [markdown]
# ### Extracting Artist Details

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'], 
                               'artist_name': artist['name'], 
                               'external_url': artist['href']}                
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '4GNC7GD6oZMSxPGyXy4MNB',
#   'artist_name': 'Lewis Capaldi',
#   'external_url': 'https://api.spotify.com/v1/artists/4GNC7GD6oZMSxPGyXy4MNB'},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'artist_name': 'Harry Styles',
#   'external_url': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'artist_name': 'Daft Punk',
#   'external_url': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
# ...

# %% [markdown]
# ### Extracting Song Details

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'song_name': 'Blinding Lights',
#   'duration_ms': 200040,
#   'url': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b',
#   'popularity': 87,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '7qiZfU4dY1lWllzX7mPBI3',
#   'song_name': 'Shape of You',
#   'duration_ms': 233712,
#   'url': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3',
#   'popularity': 85,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '7qEHsqek33rTcFNT9PFqLf',
#   'song_name': 'Someone You Loved',
#   'duration_ms': 182160,
#   'url': 'https://open.spotify.com/track/7qEHsqek33rTcFNT9PFqLf',
#   'popularity': 85,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '5658aM19fA3JVwTK6eQX70',
#   'artist_id': '4GNC7GD6oZMSxPGyXy4MNB'},
# ...

# %% [markdown]
# ### Converting Album Details to Dataframes

# %%
album_df = pd.DataFrame.from_dict(album_list)
album_df.head()
# Out:
#                  album_id                               album_name  \
# 0  4yP0hdKOZPNshxUOjY0cZj                              After Hours
# 1  3T4tUhGYeRNVUGevb0wThu                               ÷ (Deluxe)
# 2  5658aM19fA3JVwTK6eQX70  Divinely Uninspired To A Hellish Extent
# 3  5r36AJ6VOJtp00oxSkBZ5h                            Harry's House
# 4  09fggMHib4YkOtwQNXEBII                                  Starboy
#
#   album_release_date  album_total_tracks  \
# 0         2020-03-20                  14
# 1         2017-03-03                  16
# 2         2019-05-17                  12
# 3         2022-05-20                  13
# 4         2016-11-25                  18
#
#                                            album_url
# 0  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2  https://open.spotify.com/album/5658aM19fA3JVwT...
# 3  https://open.spotify.com/album/5r36AJ6VOJtp00o...
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            100 non-null    object
#  1   album_name          100 non-null    object
#  2   album_release_date  100 non-null    object
#  3   album_total_tracks  100 non-null    int64
#  4   album_url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
# converting album release date to proper date format
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'], errors= 'coerce')

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            91 non-null     object
#  1   album_name          91 non-null     object
#  2   album_release_date  89 non-null     datetime64[ns]
#  3   album_total_tracks  91 non-null     int64
#  4   album_url           91 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.3+ KB

# %%
# deleting albums duplicate album id's
album_df = album_df.drop_duplicates('album_id')

# %% [markdown]
# ### Converting Artist Details to Dataframes

# %%
artist_df = pd.DataFrame(artist_list)
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 1  6eUKZXaKkcviH0Ku9w2n3V     Ed Sheeran
# 2  4GNC7GD6oZMSxPGyXy4MNB  Lewis Capaldi
# 3  6KImCVD70vtIoJWnq6nGn3   Harry Styles
# 4  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 1  https://api.spotify.com/v1/artists/6eUKZXaKkcv...
# 2  https://api.spotify.com/v1/artists/4GNC7GD6oZM...
# 3  https://api.spotify.com/v1/artists/6KImCVD70vt...
# 4  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...

# %%
artist_df= artist_df.drop_duplicates('artist_id')

# %% [markdown]
# ### Converting Song Details to Dataframes

# %%
song_df = pd.DataFrame(song_list)
song_df.head()
# Out:
#                   song_id          song_name  duration_ms  \
# 0  0VjIjW4GlUZAMYd2vXMi3b    Blinding Lights       200040
# 1  7qiZfU4dY1lWllzX7mPBI3       Shape of You       233712
# 2  7qEHsqek33rTcFNT9PFqLf  Someone You Loved       182160
# 3  4Dvkj6JhhA12EX05fT7y2e          As It Was       167303
# 4  5aAx2yezTd8zXrkmtKl66Z            Starboy       230453
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0VjIjW4GlUZAMYd...          87
# 1  https://open.spotify.com/track/7qiZfU4dY1lWllz...          85
# 2  https://open.spotify.com/track/7qEHsqek33rTcFN...          85
# 3  https://open.spotify.com/track/4Dvkj6JhhA12EX0...          86
# 4  https://open.spotify.com/track/5aAx2yezTd8zXrk...           6
#
#              song_added                album_id               artist_id
# 0  2024-02-15T21:57:53Z  4yP0hdKOZPNshxUOjY0cZj  1Xyo4u8uXC1ZmMpatF05PJ
# 1  2024-02-15T21:57:53Z  3T4tUhGYeRNVUGevb0wThu  6eUKZXaKkcviH0Ku9w2n3V
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      99 non-null     object
#  1   song_name    99 non-null     object
#  2   duration_ms  99 non-null     int64
#  3   url          99 non-null     object
#  4   popularity   99 non-null     int64
#  5   song_added   99 non-null     object
#  6   album_id     99 non-null     object
#  7   artist_id    99 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 7.0+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'], errors= 'coerce')
# Out:
# C:\Users\gogin\AppData\Local\Temp\ipykernel_20104\950213236.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_df['song_added'] = pd.to_datetime(song_df['song_added'], errors= 'coerce')

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      99 non-null     object
#  1   song_name    99 non-null     object
#  2   duration_ms  99 non-null     int64
#  3   url          99 non-null     object
#  4   popularity   99 non-null     int64
#  5   song_added   99 non-null     datetime64[ns, UTC]
#  6   album_id     99 non-null     object
#  7   artist_id    99 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 7.0+ KB

# %%
# deleting duplicates
song_df = song_df.drop_duplicates('song_id')
